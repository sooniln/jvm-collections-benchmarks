// %%
%useLatestDescriptors
%use dataframe
%use kandy

// %%
// > memory.txt is expected to hold the ouput of "./gradlew runMemoryMeasurement"
val cpu = DataFrame.read("../benchmark-results/libraries.csv")

// %%
cpu
    .filter { "benchmark"<String>() == "IntMap.getMiss" && "order"<String>() == "random" }
    .plot {
        line {
            x("size") {
                axis{
                    name = "# of Elements (log scale)"
                    breaks(format = "d")
                }
                scale = continuous(transform = Transformation.LOG2)
            }
            y("median") {
                axis.name = "Time (log scale)"
                axis.breaksLabeled()
                scale = continuous(transform = Transformation.LOG10)
            }
            color("library") {
                legend.name = ""
                /*scale = categorical(
                    "FastCollect" to Color.RED,
                    "Fastutil" to Color.BLUE,
                    "HashSmith" to Color.YELLOW,
                    "KDS" to Color.GREEN,
                    "Kotlin" to Color.PURPLE,
                )*/
            }
        }
        layout {
            title = "Int Set PutMiss Benchmark"
            size = 800 to 400
        }

        /*vLine {
            xIntercept.constant(8000)
            type = LineType.DASHED
            width = 1.0
        }
        text {
            x.constant(8000)
            y.constant(20)
            label = "L1 Cache"
        }

        vLine {
            xIntercept.constant(250000)
            type = LineType.DASHED
            width = 1.0
        }
        text {
            x.constant(250000)
            y.constant(20)
            label = "L2 Cache"
        }*/
    }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='800' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;VBeA5m&quot; >&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 800.0,
//        height: 400.0
//    };
//
// ...
